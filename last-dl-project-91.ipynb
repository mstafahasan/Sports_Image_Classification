# %%
import os

# Path to the dataset in Kaggle environment
dataset_path = '/kaggle/input/sports-image-classification/dataset/'

# List all files in the dataset directory
file_names = os.listdir(dataset_path)

print(file_names[:5])
print("you dataset is imported succefully ")
# Out:
# ['sample_submission.csv', 'train.csv', 'test.csv', 'test', 'train']
# you dataset is imported succefully

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.utils import class_weight
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers, regularizers
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard,  LearningRateScheduler
import datetime
import os
import cv2
import plotly.graph_objects as go
import plotly.express as px
from scipy.stats import pointbiserialr
from statsmodels.stats.outliers_influence import variance_inflation_factor
print("all imports is successfully imported ")
# Out:
# 2025-05-06 03:31:47.790375: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746502308.100600   15956 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746502308.175320   15956 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# all imports is successfully imported

# %%
# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Part I: Data Preparation

# 1. Load and Describe the Data
# Path to the dataset in Kaggle environment
train_data_path = '/kaggle/input/sports-image-classification/dataset/train.csv'
test_data_path = '/kaggle/input/sports-image-classification/dataset/test.csv'

# Load the CSV files
train_df = pd.read_csv(train_data_path)
test_df = pd.read_csv(test_data_path)
print("the data imported successfully")
# Out:
# the data imported successfully

# %%
print("Train CSV Info (8227 images):")
print(train_df.info())
print("\nTrain CSV Head:")
print(train_df.head())
print("\nTest CSV Info (2056 images):")
print(test_df.info())
print("\nTest CSV Head:")
print(test_df.head())
# Out:
# Train CSV Info (8227 images):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8227 entries, 0 to 8226
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image_ID  8227 non-null   object
#  1   label     8227 non-null   object
# dtypes: object(2)
# memory usage: 128.7+ KB
# None
#
# Train CSV Head:
#          image_ID      label
# 0  7c225f7b61.jpg  Badminton
# 1         b31.jpg  Badminton
# 2  acb146546c.jpg  Badminton
# 3  0e62f4d8f2.jpg  Badminton
# 4  cfd2c28c74.jpg    Cricket
#
# Test CSV Info (2056 images):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2056 entries, 0 to 2055
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image_ID  2056 non-null   object
# dtypes: object(1)
# memory usage: 16.2+ KB
# None
#
# Test CSV Head:
#          image_ID
# 0  f5e13966e7.jpg
# 1  6674191b4e.jpg
# 2  91b5f8b7a9.jpg
# 3  393119b6d6.jpg
# 4  1ce5f81578.jpg

# %%
image_col = 'image_ID'
label_col = 'label'

# %%
print("\nLabel Distribution:")
print(train_df[label_col].value_counts())
# Out:
# Label Distribution:
# label
# Cricket      1556
# Wrestling    1471
# Tennis       1445
# Badminton    1394
# Soccer       1188
# Swimming      595
# Karate        578
# Name: count, dtype: int64

# %%
# 2. Clean the Data
print("\nMissing Values in Train CSV:")
print(train_df.isnull().sum())
train_df.dropna(inplace=True)
# Out:
# Missing Values in Train CSV:
# image_ID    0
# label       0
# dtype: int64

# %%
print("\nNumber of Duplicates in Train CSV:", train_df.duplicated().sum())
train_df.drop_duplicates(inplace=True)
# Out:
# Number of Duplicates in Train CSV: 0

# %%
def verify_images(df, folder_path):
    missing_images = []
    for idx, row in df.iterrows():
        # Adjusted path to reflect Kaggle input directory
        img_path = os.path.join(folder_path, row[image_col])
        if not os.path.exists(img_path):
            missing_images.append(row[image_col])
    return missing_images

# Correct path to the dataset in Kaggle environment
train_images_folder = '/kaggle/input/sports-image-classification/dataset/train'

# Now call the function to verify images
missing_train_images = verify_images(train_df, train_images_folder)
print("\nMissing Training Images:", len(missing_train_images))
# Out:
# Missing Training Images: 0

# %%
# 3. Load Images and Prepare for PCA
IMG_SIZE = 64
CHANNELS = 3  # Set to 3 for RGB;

# %%
def load_images(df, folder_path, img_size=IMG_SIZE, for_pca=True):
    images = []
    labels = []
    for idx, row in df.iterrows():
        img_path = os.path.join(folder_path, row[image_col])
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)  # Load as RGB (3 channels)
        # To use grayscale (1 channel), replace the above line with:
        # img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = cv2.resize(img, (img_size, img_size))
            if CHANNELS == 3:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for consistency
            if for_pca:
                images.append(img.flatten())  # Flatten: 64x64x3 = 12288 for RGB, 64x64x1 = 4096 for grayscale
            else:
                images.append(img)  # Shape: (64, 64, 3) for RGB, (64, 64) for grayscale
            labels.append(row[label_col])
    return np.array(images), np.array(labels)
print("load image function run successfully")
# Out:
# load image function run successfully

# %%
X_pca, y = load_images(train_df, '/kaggle/input/sports-image-classification/dataset/train', for_pca=True)
X_cnn, _ = load_images(train_df, '/kaggle/input/sports-image-classification/dataset/train', for_pca=False)
X_cnn = X_cnn.reshape(-1, IMG_SIZE, IMG_SIZE, CHANNELS)  # Shape for CNN: (samples, 64, 64, 3) for RGB
# To use grayscale, ensure CHANNELS = 1 above, and this line will reshape to (samples, 64, 64, 1)

# %%
# 4. PCA Analysis
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_pca)

pca = PCA()
pca.fit(X_scaled)
explained_variance_ratio = pca.explained_variance_ratio_

# Plot the cumulative explained variance
plt.figure(figsize=(8, 6))
plt.plot(np.cumsum(explained_variance_ratio))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Explained Variance')

# Display the plot instead of saving it
plt.show()  # This will show the plot


n_components = np.argmax(np.cumsum(explained_variance_ratio) >= 0.95) + 1
print(f"\nNumber of components explaining 95% variance: {n_components}")
if n_components < X_pca.shape[1] * 0.5:
    print("PCA is useful: Significant dimensionality reduction achieved.")
    pca = PCA(n_components=n_components)
    X_pca_transformed = pca.fit_transform(X_scaled)
else:
    print("PCA is not useful: Most features are needed to explain variance.")
    X_pca_transformed = X_scaled

# %%
# Add PCA Scatter Plot: Project data onto first two components
pca_2d = PCA(n_components=2)
X_pca_2d = pca_2d.fit_transform(X_scaled)  # Shape: (8227, 2)

# Explained variance for the first two components
var_pc1 = pca_2d.explained_variance_ratio_[0] * 100
var_pc2 = pca_2d.explained_variance_ratio_[1] * 100

# Create a scatter plot, coloring by sport labels
plt.figure(figsize=(10, 8))
unique_labels = np.unique(y)
colors = plt.cm.get_cmap('tab10', len(unique_labels))  # Use tab10 colormap for distinct colors

for idx, label in enumerate(unique_labels):
    mask = y == label
    plt.scatter(X_pca_2d[mask, 0], X_pca_2d[mask, 1], 
                label=label, color=colors(idx), alpha=0.6, s=30)

plt.xlabel(f'Principal Component 1 ({var_pc1:.2f}% variance)')
plt.ylabel(f'Principal Component 2 ({var_pc2:.2f}% variance)')
plt.title('PCA: 2D Projection of Sports Images')
plt.legend()
plt.show()

# %%
# 5. Encode Labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
class_names = le.classes_

# %%
# Print original and encoded labels
print("Original Labels:", y[:10])  # Print the first 10 original labels
print("Encoded Labels:", y_encoded[:10])  # Print the first 10 encoded labels

# Print a mapping between original labels and encoded values
label_mapping = dict(zip(le.classes_, range(len(le.classes_))))
print("Label to Encoded Value Mapping:", label_mapping)

# If you want to print the reverse mapping (encoded value to original label):
reverse_label_mapping = {v: k for k, v in label_mapping.items()}
print("Encoded Value to Label Mapping:", reverse_label_mapping)
# Out:
# Original Labels: ['Badminton' 'Badminton' 'Badminton' 'Badminton' 'Cricket' 'Tennis'
#  'Badminton' 'Swimming' 'Badminton' 'Badminton']
# Encoded Labels: [0 0 0 0 1 5 0 4 0 0]
# Label to Encoded Value Mapping: {'Badminton': 0, 'Cricket': 1, 'Karate': 2, 'Soccer': 3, 'Swimming': 4, 'Tennis': 5, 'Wrestling': 6}
# Encoded Value to Label Mapping: {0: 'Badminton', 1: 'Cricket', 2: 'Karate', 3: 'Soccer', 4: 'Swimming', 5: 'Tennis', 6: 'Wrestling'}

# %%
X_train, X_val, y_train, y_val = train_test_split(X_cnn, y_encoded, test_size=0.2, random_state=42)

# %%
# Compute the mean and standard deviation for the training set
train_mean = np.mean(X_train, axis=(0, 1, 2))  # Mean for each channel (RGB)
train_std = np.std(X_train, axis=(0, 1, 2))  # Std for each channel (RGB)

# Standardize the data using the mean and std computed from the training set
X_train_standardized = (X_train - train_mean) / train_std
X_val_standardized = (X_val - train_mean) / train_std  # Use the training set's mean and std for validation set

# Define the ImageDataGenerators for data augmentation and rescaling
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)
val_datagen = ImageDataGenerator()  # No augmentation for validation set

# Apply the standardization (mean subtraction and division by std) to the train and validation sets
train_generator = train_datagen.flow(X_train_standardized, y_train, batch_size=32)
val_generator = val_datagen.flow(X_val_standardized, y_val, batch_size=32)

# %%
# 5. Check Consistency Between Training and Validation Data Standardization
print("\nEnsure that the training and validation data have similar mean and standard deviation:")
print("Training Mean:", np.mean(X_train_standardized, axis=(0, 1, 2)))
print("Validation Mean:", np.mean(X_val_standardized, axis=(0, 1, 2)))

print("\nTraining Std:", np.std(X_train_standardized, axis=(0, 1, 2)))
print("Validation Std:", np.std(X_val_standardized, axis=(0, 1, 2)))
# Out:
# Ensure that the training and validation data have similar mean and standard deviation:
# Training Mean: [-3.73969275e-15 -8.25435816e-14 -1.51779409e-14]
# Validation Mean: [-0.01077603 -0.00417199 -0.01862566]
#
# Training Std: [1. 1. 1.]
# Validation Std: [0.99881143 1.00159806 0.99471388]

# %%
#visualize all data (not train data only )
plt.figure(figsize=(10, 6))
train_df[label_col].value_counts().plot(kind='bar')
plt.title('Label Distribution')
plt.xlabel('Sport')
plt.ylabel('Count')

# Show the plot in the notebook instead of saving it
plt.show()

# %%
# 8. Visualize Data



def visualize_data(train_images, train_labels, class_names):

    # Label distribution bar chart
    plt.figure(figsize=(10, 6))
    unique, counts = np.unique(train_labels, return_counts=True)
    plt.bar(class_names, counts)
    plt.title('Class Distribution')
    plt.xlabel('Sports Class')
    plt.ylabel('Number of Images')
    plt.xticks(rotation=45)
    plt.show()

    # Pie chart for class distribution
    plt.figure(figsize=(8, 8))
    plt.pie(counts, labels=class_names, autopct='%1.1f%%', startangle=90)
    plt.title('Class Distribution (Pie Chart)')
    plt.show()

    # Image montage by class
    num_classes = len(class_names)
    fig, axes = plt.subplots(num_classes, 3, figsize=(12, 4 * num_classes))
    for i, class_name in enumerate(class_names):
        class_indices = np.where(train_labels == i)[0]
        sample_indices = np.random.choice(class_indices, 3, replace=False)
        for j, idx in enumerate(sample_indices):
            axes[i, j].imshow(train_images[idx])
            axes[i, j].axis('off')
            if j == 1:
                axes[i, j].set_title(f'{class_name}')
    plt.tight_layout()
    plt.show()

    # Pixel intensity histograms
    plt.figure(figsize=(12, 6))
    for i, class_name in enumerate(class_names):
        class_images = train_images[train_labels == i]
        mean_intensities = np.mean(class_images, axis=(1, 2, 3))  # Averaging over the image dimensions
        plt.hist(mean_intensities, bins=20, alpha=0.7, label=class_name)
    plt.title('Pixel Intensity Distribution by Class')
    plt.xlabel('Mean Pixel Intensity')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

# Example usage
visualize_data(X_train, y_train, class_names)

# %%
# 9. Correlation Analysis (Interactive HTML Heatmap with Negative Correlations)
# Compute correlation matrix
pixel_corr = pd.DataFrame(X_pca).iloc[::5, ::5].corr()  # Shape: (2458, 2458)

# Check for negative correlations in the first subsampled matrix
print("\nChecking for negative correlations in first subsampled matrix:")
negative_corrs = pixel_corr[pixel_corr < 0].stack()
if not negative_corrs.empty:
    print(f"Found {len(negative_corrs)} negative correlations. Sample:")
    print(negative_corrs.head())
else:
    print("No negative correlations found.")

# Subsample to reduce size while ensuring negative correlations are included
step = 100  # Reduces from 2458 to ~25 (2458 / 100)
# Select indices to include some negative correlations
# Find pairs with negative correlations
neg_pairs = np.where(pixel_corr < -0.1)  # Threshold to find significant negative correlations
neg_indices = list(set(neg_pairs[0]))  # Unique indices with negative correlations

# Ensure we include some indices with negative correlations
num_indices_to_include = min(5, len(neg_indices))  # Include up to 5 indices with negative correlations
selected_neg_indices = neg_indices[:num_indices_to_include] if neg_indices else []

# Create a list of indices for subsampling, including negative correlation indices
subsample_indices = list(range(0, pixel_corr.shape[0], step))  # Default subsampling: 0, 100, ..., 2400
# Add some indices with negative correlations
for idx in selected_neg_indices:
    closest_subsample_idx = (idx // step) * step  # Align with step
    if closest_subsample_idx not in subsample_indices:
        subsample_indices.append(closest_subsample_idx)

subsample_indices = sorted(set(subsample_indices))  # Remove duplicates and sort
subsample_indices = subsample_indices[:25]  # Limit to 25 indices to keep heatmap manageable

# Subsample the correlation matrix using selected indices
subsampled_corr = pixel_corr.iloc[subsample_indices, subsample_indices].values

# Map subsampled indices back to original indices
original_indices = np.array(subsample_indices) * 5  # Map to original feature space: [0, 500, ..., 12000]

# Create tick labels for the heatmap
num_ticks = min(10, len(original_indices))
tick_positions = np.linspace(0, len(original_indices) - 1, num_ticks).astype(int)
tick_labels = original_indices[tick_positions]

# Create text annotations (rounded correlation values)
text_annotations = np.round(subsampled_corr, 2).astype(str)

# Create interactive heatmap with Plotly
fig = go.Figure(data=go.Heatmap(
    z=subsampled_corr,
    x=original_indices,
    y=original_indices,
    colorscale='RdBu',
    zmin=-1, zmax=1,
    colorbar=dict(title='Correlation'),
    text=text_annotations,
    texttemplate="%{text}",
    textfont=dict(size=10),
))

fig.update_layout(
    title='Pixel Correlation Heatmap (Subsampled)',
    xaxis_title='Pixel Index (Subsampled)',
    yaxis_title='Pixel Index (Subsampled)',
    xaxis=dict(tickvals=tick_labels, ticktext=[str(val) for val in tick_labels]),
    yaxis=dict(tickvals=tick_labels, ticktext=[str(val) for val in tick_labels]),
    autosize=True,
    margin=dict(l=50, r=50, t=100, b=50),
)

fig.write_html(
    'pixel_correlation_interactive.html',
    include_plotlyjs='cdn',
    post_script="""
    const style = document.createElement('style');
    style.innerHTML = `
        #graph { width: 100vw !important; height: 100vh !important; }
        body { margin: 0; padding: 0; overflow: hidden; }
    `;
    document.head.appendChild(style);
    """
)
print("\nInteractive heatmap saved as 'pixel_correlation_interactive.html'")
print("Open the HTML file in a browser to view the full-screen heatmap .")
# Out:
# Checking for negative correlations in first subsampled matrix:
# Found 6 negative correlations. Sample:
# 2635   11835   -0.002409
# 3020   11835   -0.007049
# 7960   11835   -0.006249
# 11835  2635    -0.002409
#        3020    -0.007049
# dtype: float64
#
# Interactive heatmap saved as 'pixel_correlation_interactive.html'
# Open the HTML file in a browser to view the full-screen heatmap .

# %%
# Part II: Training a Neural Network

# Requirement 1: Implement a CNN model
def create_cnn_model(input_shape=(224, 224, 3), num_classes=6):
    """
    Creates an enhanced CNN model for sports image classification.
    - Deeper network
    - Batch Normalization
    - Dropout for regularization
    """
    model = keras.Sequential([
        # Block 1
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Block 2
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Block 3
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Classification Head
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.4),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model


# Requirement 2: Write a training function
def train_model(model, optimizer, batch_size, epochs=50):
    """
    Trains the model with early stopping and learning rate scheduling.
    
    Parameters:
    - model: CNN model to train
    - optimizer: Optimizer instance
    - batch_size: Batch size for training
    - epochs: Maximum number of epochs
    
    Returns:
    - History object
    """
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
    
    # Define the learning rate schedule
    lr_schedule = ExponentialDecay(initial_learning_rate=0.001, decay_steps=10000, decay_rate=0.9, staircase=True)
    
    # Wrap the schedule to ensure the output is a Python float
    def schedule(epoch):
        lr = lr_schedule(epoch)
        return float(lr)  # Explicitly cast to Python float
    
    lr_scheduler = LearningRateScheduler(schedule)
    
    log_dir = "/kaggle/working/logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    history = model.fit(
        train_generator,
        epochs=epochs,
        validation_data=val_generator,
        callbacks=[early_stopping, lr_scheduler, tensorboard_callback],
        verbose=1
    )
    return history

# Requirement 3: Evaluate the model
def evaluate_model(model):
    """
    Evaluates the model on training and validation sets.
    
    Parameters:
    - model: Trained CNN model
    
    Returns:
    - Tuple of (train_accuracy, val_accuracy)
    """
    train_loss, train_acc = model.evaluate(train_generator, verbose=0)
    val_loss, val_acc = model.evaluate(val_generator, verbose=0)
    print(f"Train Accuracy: {train_acc:.4f}, Validation Accuracy: {val_acc:.4f}")
    return train_acc, val_acc
def update_generators(batch_size):
    """
    Updates data generators with a new batch size.
    
    Parameters:
    - batch_size: New batch size
    """
    global train_generator, val_generator
    train_generator = train_datagen.flow(X_train_standardized, y_train, batch_size=batch_size)
    val_generator = val_datagen.flow(X_val_standardized, y_val, batch_size=batch_size)

# %%
BEST_PARAMS = {
    'batch_size': 32,          # From your best_batch
    'num_layers': 3,           # From your best_layers (unused in structure)
    'dropout_rate': 0.2,       # From your best_dropout
    'weight_decay': 0.0,       # From your best_wd
    'optimizer': 'Adam',       # From your best_opt
    'learning_rate': 0.001     # Default for Adam
}

# ========= CONFIGURATION =========
IMG_SIZE    = 64
CHANNELS    = 3
NUM_CLASSES = 7   # adjust to your number of sports classes

IMAGE_COL = 'image_ID'
LABEL_COL = 'label'

# Paths in Kaggle environment
TRAIN_IMG_FOLDER = '/kaggle/input/sports-image-classification/dataset/train'
TEST_IMG_FOLDER  = '/kaggle/input/sports-image-classification/dataset/test'
TRAIN_CSV        = '/kaggle/input/sports-image-classification/dataset/train.csv'
TEST_CSV         = '/kaggle/input/sports-image-classification/dataset/test.csv'

# ===== FUNCTIONS DEFINITION =====
def verify_images(df, folder_path):
    missing = []
    for _, row in df.iterrows():
        path = os.path.join(folder_path, row[IMAGE_COL])
        if not os.path.exists(path):
            missing.append(row[IMAGE_COL])
    return missing


def load_images(df, folder_path, img_size=IMG_SIZE):
    imgs, labels = [], []
    for _, row in df.iterrows():
        img_path = os.path.join(folder_path, row[IMAGE_COL])
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        if img is None:
            continue
        img = cv2.resize(img, (img_size, img_size))
        if CHANNELS == 3:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        imgs.append(img)
        labels.append(row[LABEL_COL])
    return np.array(imgs), np.array(labels)


def load_test_images(df, folder_path, img_size=IMG_SIZE):
    imgs = []
    for _, row in df.iterrows():
        img_path = os.path.join(folder_path, row[IMAGE_COL])
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        if img is None:
            continue
        img = cv2.resize(img, (img_size, img_size))
        if CHANNELS == 3:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        imgs.append(img)
    return np.array(imgs)

from tensorflow.keras.preprocessing.image import ImageDataGenerator

def create_cnn_model(input_shape=(IMG_SIZE, IMG_SIZE, CHANNELS), num_classes=NUM_CLASSES):
    weight_decay = BEST_PARAMS.get('weight_decay', 0.001)

    model = keras.Sequential([
        # Block 1
        layers.Conv2D(32, (3, 3), activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(weight_decay), input_shape=input_shape),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(weight_decay)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Block 2
        layers.Conv2D(64, (3, 3), activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(weight_decay)),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(weight_decay)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Block 3
        layers.Conv2D(128, (3, 3), activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(weight_decay)),
        layers.BatchNormalization(),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(weight_decay)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # Classifier
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.4),
        layers.Dense(128, activation='relu',
                     kernel_regularizer=regularizers.l2(weight_decay)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

def train_model(train_gen, val_gen, class_weight_dict, epochs=50):
    model = create_cnn_model()
    model.compile(
        optimizer=Adam(learning_rate=BEST_PARAMS['learning_rate']),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    callbacks = [
        EarlyStopping(patience=5, monitor='val_accuracy', restore_best_weights=True),
        ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True)
    ]
    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=epochs,
        callbacks=callbacks,
        class_weight=class_weight_dict
    )
    return model, history


def plot_history(history):
    plt.figure()
    plt.plot(history.history['accuracy'], label='train acc')
    plt.plot(history.history['val_accuracy'], label='val acc')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
# ===== TRAINING PART for model with best hyper parameters =====
# 1) Load and verify training data
train_df = pd.read_csv(TRAIN_CSV)
missing = verify_images(train_df, TRAIN_IMG_FOLDER)
print(f"Missing train images: {len(missing)}")

# 2) Load all images and labels
X_all, y_all_raw = load_images(train_df, TRAIN_IMG_FOLDER)

# 3) Encode labels
le = LabelEncoder()
y_all = le.fit_transform(y_all_raw)

# 4) Split into train/val sets
X_train, X_val, y_train, y_val = train_test_split(
    X_all, y_all,
    test_size=0.2,
    random_state=42,
    stratify=y_all
)

# 5) Compute class weights
weights = class_weight.compute_class_weight(
    'balanced', classes=np.unique(y_train), y=y_train
)
class_weight_dict = dict(enumerate(weights))

# 6) Standardize data
train_mean = X_train.mean(axis=(0,1,2))
train_std  = X_train.std(axis=(0,1,2))
X_train_std = (X_train - train_mean) / train_std
X_val_std   = (X_val   - train_mean) / train_std

# 7) Data generators
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)
val_datagen  = ImageDataGenerator()

train_gen = train_datagen.flow(
    X_train_std, y_train,
    batch_size=BEST_PARAMS['batch_size']
)
val_gen = val_datagen.flow(
    X_val_std, y_val,
    batch_size=BEST_PARAMS['batch_size']
)

# 8) Train model
model, history = train_model(train_gen, val_gen, class_weight_dict)

# 9) Plot training history
plot_history(history)

# %%
# ===== TESTING & SUBMISSION PART for model with best hyper parameter =====
# 1) Load and standardize test data
test_df = pd.read_csv(TEST_CSV)
X_test = load_test_images(test_df, TEST_IMG_FOLDER)
X_test_std = (X_test - train_mean) / train_std

test_datagen = ImageDataGenerator()
test_gen = test_datagen.flow(
    X_test_std,
    shuffle=False,
    batch_size=BEST_PARAMS['batch_size']
)

# 2) Predict and inspect distribution
preds = model.predict(test_gen)
pred_classes = np.argmax(preds, axis=1)
uniq, counts = np.unique(pred_classes, return_counts=True)
print("Prediction distribution:", dict(zip(uniq, counts)))

# 3) Save submission.csv
pred_labels = le.inverse_transform(pred_classes)
submission = pd.DataFrame({
    IMAGE_COL: test_df[IMAGE_COL],
    LABEL_COL: pred_labels
})
submission.to_csv('submission.csv', index=False)

# 4) Save final model
model.save('best_sports_classifier.keras')

# %% [markdown]
# # All Steps in more organized way

# %% [markdown]
# # Functions definition

# %%
# # ========= INITIAL PARAMETERS =========
BEST_PARAMS = {
    'batch_size': 32,
    'num_layers': 3,           # Not used, but kept for reference
    'dropout_rate': 0.2,       # Optional override
    'weight_decay': 0.001,     # Used in model
    'optimizer': 'Adam',
    'learning_rate': 0.001
}
from tensorflow.keras import mixed_precision
from tensorflow.keras import layers, models, regularizers

mixed_precision.set_global_policy('mixed_float16')

# ========= CONFIGURATION =========
IMG_SIZE = 64
CHANNELS    = 3
NUM_CLASSES = 7
IMAGE_COL   = 'image_ID'
LABEL_COL   = 'label'
INPUT_SHAPE = (IMG_SIZE, IMG_SIZE, CHANNELS)

# Paths
TRAIN_CSV     = '/kaggle/input/sports-image-classification/dataset/train.csv'
TEST_CSV      = '/kaggle/input/sports-image-classification/dataset/test.csv'
TRAIN_IMG_DIR = '/kaggle/input/sports-image-classification/dataset/train'
TEST_IMG_DIR  = '/kaggle/input/sports-image-classification/dataset/test'

def build_cnn_model(num_layers=3, dropout_rate=0.3, weight_decay=1e-4):
    """
    Builds a custom CNN with variable number of convolutional blocks,
    dropout, and L2 regularization.
    
    Parameters:
    - num_layers: int, number of conv blocks to use (2–5 recommended)
    - dropout_rate: float, dropout rate for regularization
    - weight_decay: float, L2 regularization factor
    
    Returns:
    - Compiled Keras model
    """
    model = models.Sequential()
    model.add(layers.Input(shape=INPUT_SHAPE))

    for i in range(num_layers):
        filters = min(32 * (2 ** i), 256)  # Gradually increase, max out at 256
        model.add(layers.Conv2D(filters, kernel_size=(3, 3), padding='same', activation='relu',
                                kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(layers.BatchNormalization())
        model.add(layers.Conv2D(filters, kernel_size=(3, 3), padding='same', activation='relu',
                                kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(layers.BatchNormalization())
        model.add(layers.MaxPooling2D(pool_size=(2, 2)))
        model.add(layers.Dropout(dropout_rate))

    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(256, activation='relu',
                           kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.6))
    model.add(layers.Dense(7, activation='softmax'))

    return model

print("run")
# Out:
# run

# %%
# ===== FUNCTIONS DEFINITION =====
def verify_images(df, folder_path):
    missing = []
    for _, row in df.iterrows():
        path = os.path.join(folder_path, row[IMAGE_COL])
        if not os.path.exists(path):
            missing.append(row[IMAGE_COL])
    return missing


def load_images(df, folder_path, img_size=IMG_SIZE):
    imgs, labels = [], []
    for _, row in df.iterrows():
        img_path = os.path.join(folder_path, row[IMAGE_COL])
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        if img is None:
            continue
        img = cv2.resize(img, (img_size, img_size))
        if CHANNELS == 3:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        imgs.append(img)
        labels.append(row[LABEL_COL])
    return np.array(imgs), np.array(labels)


def load_test_images(df, folder_path, img_size=IMG_SIZE):
    imgs = []
    for _, row in df.iterrows():
        img_path = os.path.join(folder_path, row[IMAGE_COL])
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        if img is None:
            continue
        img = cv2.resize(img, (img_size, img_size))
        if CHANNELS == 3:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        imgs.append(img)
    return np.array(imgs)

# %% [markdown]
# # LOAD & PREPARE

# %%
# Load and clean CSV
df = pd.read_csv(TRAIN_CSV)
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
print(f"Samples: {len(df)}; Missing: {len(verify_images(df, TRAIN_IMG_DIR))}")

# # Create generators (train/val/test)
# train_gen, val_gen, test_gen = create_generators(
#     TRAIN_CSV, TEST_CSV,
#     TRAIN_IMG_DIR, TEST_IMG_DIR,
#     img_size=IMG_SIZE,
#     batch_size=BEST_PARAMS['batch_size']
# )

# Compute class weights
le = LabelEncoder()
y_labels = le.fit_transform(df['label'])

cw_values = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_labels),
    y=y_labels
)
cw = dict(enumerate(cw_values))

from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
# Out:
# Samples: 8227; Missing: 0

# %%
# ==== LOAD & PREPARE DATA (SKLEARN SPLIT) ====

# Load CSVs
train_df = pd.read_csv(TRAIN_CSV)
test_df  = pd.read_csv(TEST_CSV)

# Drop issues
train_df.dropna(inplace=True)
train_df.drop_duplicates(inplace=True)

# Load images and labels
X, y = load_images(train_df, TRAIN_IMG_DIR, img_size=IMG_SIZE)

# Label encoding
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train/Val split
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(
    X, y_encoded, test_size=0.15, stratify=y_encoded, random_state=42
)

# Normalize
X_train = X_train / 255.0
X_val   = X_val / 255.0

# Test data (optional for later evaluation)
X_test = load_test_images(test_df, TEST_IMG_DIR, img_size=IMG_SIZE)
X_test = X_test / 255.0

# %%
# # ==== Augment Training Data Before Hyperparameter Exploration ====
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# def augment_images(X, y):
#     datagen = ImageDataGenerator(
#         rotation_range=20,
#         width_shift_range=0.2,
#         height_shift_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True
#     )

#     augmented_X, augmented_y = [], []
#     for i in range(len(X)):
#         x = X[i].reshape((1, *X[i].shape))
#         y_val = y[i]
#         for _ in range(4):
#             for batch in datagen.flow(x, batch_size=1):
#                 augmented_X.append(batch[0])
#                 augmented_y.append(y_val)
#                 break

#     augmented_X = np.array(augmented_X)
#     augmented_y = np.array(augmented_y)

#     # Combine original + augmented
#     X_combined = np.concatenate([X, augmented_X], axis=0)
#     y_combined = np.concatenate([y, augmented_y], axis=0)

#     return X_combined, y_combined

# #  Apply to X_train before exploring
# X_train_aug, y_train_aug = augment_images(X_train, y_train)
# print(f"Augmented Exploration Data: {X_train_aug.shape}, Labels: {y_train_aug.shape}")

# %%
def train_model_numpy(model,
                      X_train, y_train,
                      X_val, y_val,
                      optimizer_name='Adam',
                      learning_rate=0.001,
                      class_weight=None,
                      use_scheduler=True,
                      batch_size=32,
                      epochs=12):
    """
    Training function using NumPy arrays with NO augmentation — for hyperparameter exploration.
    """
    opt_cls = {'Adam': Adam, 'SGD': SGD, 'RMSprop': RMSprop}[optimizer_name]
    opt_kwargs = {'learning_rate': learning_rate}
    if optimizer_name == 'SGD':
        opt_kwargs['momentum'] = 0.9
    optimizer = opt_cls(**opt_kwargs)

    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    #  No augmentation during hyperparameter tuning
    X_train_scaled = X_train / 255.0
    X_val_scaled = X_val / 255.0

    callbacks = [EarlyStopping(patience=5, monitor='val_accuracy', restore_best_weights=True)]
    if use_scheduler:
        callbacks.append(ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2))

    history = model.fit(
        X_train_scaled, y_train,
        validation_data=(X_val_scaled, y_val),
        batch_size=batch_size,
        epochs=epochs,
        callbacks=callbacks,
        class_weight=class_weight,
        verbose=1
    )

    best_val_acc = max(history.history['val_accuracy'])
    return best_val_acc, history

# %%
# ====  Explore Number of Layers ====

layer_options = [2, 3, 4, 5, 6]
layer_results = {}

for n_layers in layer_options:
    print(f"\n Training with num_layers = {n_layers}")
    
    model = build_cnn_model(
        num_layers=n_layers,
        dropout_rate=BEST_PARAMS['dropout_rate'],
        weight_decay=BEST_PARAMS['weight_decay']
    )

    val_acc, _ = train_model_numpy(
        model,
        X_train, y_train,
        X_val, y_val,
        optimizer_name=BEST_PARAMS['optimizer'],
        learning_rate=BEST_PARAMS['learning_rate'],
        batch_size=BEST_PARAMS['batch_size']
    )

    layer_results[n_layers] = val_acc

# Plot results
plt.figure()
plt.plot(list(layer_results.keys()), list(layer_results.values()), marker='o')
plt.title('Validation Accuracy vs. Number of Layers')
plt.xlabel('Number of Layers')
plt.ylabel('Validation Accuracy')
plt.grid(True)
plt.show()

# Update best
BEST_PARAMS['num_layers'] = max(layer_results, key=layer_results.get)
print(f"\n Best num_layers = {BEST_PARAMS['num_layers']} with accuracy = {layer_results[BEST_PARAMS['num_layers']]:.4f}")
# Out:
#  Training with num_layers = 2
# I0000 00:00:1746502510.464127   15956 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1746502510.464852   15956 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/12
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746502519.240609   15992 service.cc:148] XLA service 0x784f40029580 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746502519.241474   15992 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746502519.241495   15992 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746502519.995456   15992 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  21/219 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1840 - loss: 2.8477
# I0000 00:00:1746502529.397435   15992 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 27s 50ms/step - accuracy: 0.2884 - loss: 2.5843 - val_accuracy: 0.1757 - val_loss: 2.5673 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4695 - loss: 1.8540 - val_accuracy: 0.1781 - val_loss: 2.5087 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5554 - loss: 1.5211 - val_accuracy: 0.2769 - val_loss: 2.8690 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5992 - loss: 1.3578 - val_accuracy: 0.5061 - val_loss: 1.7080 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6254 - loss: 1.2595 - val_accuracy: 0.6575 - val_loss: 1.1796 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6632 - loss: 1.1591 - val_accuracy: 0.6162 - val_loss: 1.4543 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6729 - loss: 1.1098 - val_accuracy: 0.7045 - val_loss: 1.0845 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7041 - loss: 1.0408 - val_accuracy: 0.6275 - val_loss: 1.2348 - learning_rate: 0.0010
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7169 - loss: 0.9916 - val_accuracy: 0.4850 - val_loss: 1.8706 - learning_rate: 0.0010
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7497 - loss: 0.9016 - val_accuracy: 0.6785 - val_loss: 1.1645 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7750 - loss: 0.8297 - val_accuracy: 0.7271 - val_loss: 0.9969 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7779 - loss: 0.8032 - val_accuracy: 0.7506 - val_loss: 0.8757 - learning_rate: 5.0000e-04
#
#  Training with num_layers = 3
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 28s 55ms/step - accuracy: 0.2961 - loss: 2.9564 - val_accuracy: 0.1895 - val_loss: 3.6663 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5134 - loss: 2.0356 - val_accuracy: 0.1895 - val_loss: 3.8445 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5883 - loss: 1.6972 - val_accuracy: 0.4283 - val_loss: 2.3522 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6329 - loss: 1.5100 - val_accuracy: 0.5798 - val_loss: 1.6386 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6751 - loss: 1.3804 - val_accuracy: 0.4389 - val_loss: 2.7206 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7036 - loss: 1.2578 - val_accuracy: 0.2130 - val_loss: 4.9234 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7426 - loss: 1.1286 - val_accuracy: 0.6146 - val_loss: 1.6064 - learning_rate: 5.0000e-04
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7711 - loss: 1.0343 - val_accuracy: 0.6858 - val_loss: 1.2885 - learning_rate: 5.0000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7770 - loss: 0.9961 - val_accuracy: 0.5968 - val_loss: 1.6624 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7858 - loss: 0.9412 - val_accuracy: 0.2510 - val_loss: 4.5658 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8217 - loss: 0.8483 - val_accuracy: 0.6510 - val_loss: 1.3792 - learning_rate: 2.5000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8573 - loss: 0.7542 - val_accuracy: 0.7506 - val_loss: 1.0875 - learning_rate: 2.5000e-04
#
#  Training with num_layers = 4
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 35s 68ms/step - accuracy: 0.3012 - loss: 3.5569 - val_accuracy: 0.1895 - val_loss: 3.8787 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5182 - loss: 2.5005 - val_accuracy: 0.1895 - val_loss: 4.3064 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5976 - loss: 2.1367 - val_accuracy: 0.2680 - val_loss: 2.6422 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6343 - loss: 1.8852 - val_accuracy: 0.4300 - val_loss: 2.6466 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6820 - loss: 1.6981 - val_accuracy: 0.3126 - val_loss: 3.9483 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7293 - loss: 1.4601 - val_accuracy: 0.6397 - val_loss: 1.7026 - learning_rate: 5.0000e-04
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7603 - loss: 1.3323 - val_accuracy: 0.7709 - val_loss: 1.2796 - learning_rate: 5.0000e-04
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7794 - loss: 1.2272 - val_accuracy: 0.6802 - val_loss: 1.4956 - learning_rate: 5.0000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8017 - loss: 1.1221 - val_accuracy: 0.6340 - val_loss: 1.6336 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8337 - loss: 1.0144 - val_accuracy: 0.8049 - val_loss: 1.0570 - learning_rate: 2.5000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8615 - loss: 0.9136 - val_accuracy: 0.8057 - val_loss: 1.0617 - learning_rate: 2.5000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8768 - loss: 0.8474 - val_accuracy: 0.8113 - val_loss: 1.0536 - learning_rate: 2.5000e-04
#
#  Training with num_layers = 5
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 38s 73ms/step - accuracy: 0.2651 - loss: 4.2096 - val_accuracy: 0.1757 - val_loss: 4.9383 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4894 - loss: 3.1542 - val_accuracy: 0.1757 - val_loss: 5.0929 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5895 - loss: 2.7198 - val_accuracy: 0.3368 - val_loss: 3.6912 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6383 - loss: 2.4519 - val_accuracy: 0.4980 - val_loss: 2.8963 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6718 - loss: 2.2090 - val_accuracy: 0.5741 - val_loss: 2.3811 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7108 - loss: 1.9959 - val_accuracy: 0.5036 - val_loss: 2.7801 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7252 - loss: 1.8290 - val_accuracy: 0.6794 - val_loss: 1.9190 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7584 - loss: 1.6437 - val_accuracy: 0.7320 - val_loss: 1.7177 - learning_rate: 0.0010
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7721 - loss: 1.5347 - val_accuracy: 0.6275 - val_loss: 2.0260 - learning_rate: 0.0010
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7786 - loss: 1.4555 - val_accuracy: 0.6704 - val_loss: 1.8305 - learning_rate: 0.0010
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8200 - loss: 1.2905 - val_accuracy: 0.7644 - val_loss: 1.3954 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8659 - loss: 1.1084 - val_accuracy: 0.7522 - val_loss: 1.4587 - learning_rate: 5.0000e-04
#
#  Training with num_layers = 6
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 45s 86ms/step - accuracy: 0.2344 - loss: 4.8900 - val_accuracy: 0.1757 - val_loss: 4.3286 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4706 - loss: 3.7272 - val_accuracy: 0.1757 - val_loss: 4.3061 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5685 - loss: 3.3083 - val_accuracy: 0.3538 - val_loss: 3.6182 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6149 - loss: 3.0034 - val_accuracy: 0.5951 - val_loss: 2.9045 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6693 - loss: 2.6851 - val_accuracy: 0.5117 - val_loss: 3.6181 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6844 - loss: 2.5133 - val_accuracy: 0.6810 - val_loss: 2.4228 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7268 - loss: 2.2368 - val_accuracy: 0.6713 - val_loss: 2.3929 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7464 - loss: 2.0530 - val_accuracy: 0.6996 - val_loss: 2.1754 - learning_rate: 0.0010
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7738 - loss: 1.8726 - val_accuracy: 0.5247 - val_loss: 2.8095 - learning_rate: 0.0010
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7691 - loss: 1.7719 - val_accuracy: 0.6121 - val_loss: 2.3612 - learning_rate: 0.0010
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8187 - loss: 1.5924 - val_accuracy: 0.7814 - val_loss: 1.6288 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8778 - loss: 1.3697 - val_accuracy: 0.7134 - val_loss: 1.9185 - learning_rate: 5.0000e-04
#  Best num_layers = 4 with accuracy = 0.8113

# %%
# ==== Explore Dropout Rate ====

dropout_rates = [0.2, 0.3, 0.4, 0.5]
dropout_results = {}

for rate in dropout_rates:
    print(f"\n Training with dropout_rate = {rate}")
    
    model = build_cnn_model(
        num_layers=BEST_PARAMS['num_layers'],
        dropout_rate=rate,
        weight_decay=BEST_PARAMS['weight_decay']
    )

    val_acc, _ = train_model_numpy(
        model,
        X_train, y_train,
        X_val, y_val,
        optimizer_name=BEST_PARAMS['optimizer'],
        learning_rate=BEST_PARAMS['learning_rate'],
        batch_size=BEST_PARAMS['batch_size']
    )

    dropout_results[rate] = val_acc

# Plot
plt.figure()
plt.plot(dropout_results.keys(), dropout_results.values(), marker='o')
plt.title('Validation Accuracy vs. Dropout Rate')
plt.xlabel('Dropout Rate')
plt.ylabel('Validation Accuracy')
plt.grid(True)
plt.show()

# Update
BEST_PARAMS['dropout_rate'] = max(dropout_results, key=dropout_results.get)
print(f"\n Best dropout_rate = {BEST_PARAMS['dropout_rate']} with accuracy = {dropout_results[BEST_PARAMS['dropout_rate']]:.4f}")
# Out:
#  Training with dropout_rate = 0.2
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 61ms/step - accuracy: 0.3014 - loss: 3.4988 - val_accuracy: 0.1692 - val_loss: 4.5445 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5215 - loss: 2.5321 - val_accuracy: 0.1757 - val_loss: 3.4637 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6037 - loss: 2.1254 - val_accuracy: 0.4138 - val_loss: 3.5470 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6487 - loss: 1.8806 - val_accuracy: 0.6211 - val_loss: 1.8723 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6731 - loss: 1.7004 - val_accuracy: 0.5530 - val_loss: 2.0383 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6967 - loss: 1.5204 - val_accuracy: 0.4632 - val_loss: 2.5982 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7515 - loss: 1.3148 - val_accuracy: 0.6761 - val_loss: 1.4571 - learning_rate: 5.0000e-04
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7835 - loss: 1.1968 - val_accuracy: 0.5935 - val_loss: 1.7873 - learning_rate: 5.0000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7937 - loss: 1.1303 - val_accuracy: 0.7085 - val_loss: 1.3636 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8106 - loss: 1.0526 - val_accuracy: 0.7385 - val_loss: 1.2731 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8165 - loss: 1.0125 - val_accuracy: 0.7433 - val_loss: 1.2499 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8457 - loss: 0.9325 - val_accuracy: 0.7498 - val_loss: 1.2625 - learning_rate: 5.0000e-04
#
#  Training with dropout_rate = 0.3
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 61ms/step - accuracy: 0.2877 - loss: 3.5158 - val_accuracy: 0.1757 - val_loss: 4.1722 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5028 - loss: 2.5386 - val_accuracy: 0.2130 - val_loss: 3.1836 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5901 - loss: 2.1430 - val_accuracy: 0.3911 - val_loss: 2.8892 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6370 - loss: 1.9104 - val_accuracy: 0.6073 - val_loss: 1.9026 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6632 - loss: 1.7412 - val_accuracy: 0.6097 - val_loss: 1.9183 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6956 - loss: 1.5663 - val_accuracy: 0.6551 - val_loss: 1.5982 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7125 - loss: 1.4411 - val_accuracy: 0.6081 - val_loss: 1.7547 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7257 - loss: 1.3450 - val_accuracy: 0.3150 - val_loss: 3.2617 - learning_rate: 0.0010
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7649 - loss: 1.1798 - val_accuracy: 0.7287 - val_loss: 1.3417 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7918 - loss: 1.0809 - val_accuracy: 0.7798 - val_loss: 1.1465 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8106 - loss: 1.0086 - val_accuracy: 0.7943 - val_loss: 1.0755 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8225 - loss: 0.9628 - val_accuracy: 0.7474 - val_loss: 1.1884 - learning_rate: 5.0000e-04
#
#  Training with dropout_rate = 0.4
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 61ms/step - accuracy: 0.2700 - loss: 3.5692 - val_accuracy: 0.1757 - val_loss: 3.6805 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4810 - loss: 2.6842 - val_accuracy: 0.1895 - val_loss: 3.6939 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5894 - loss: 2.1844 - val_accuracy: 0.2777 - val_loss: 3.1361 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6214 - loss: 1.9733 - val_accuracy: 0.5522 - val_loss: 2.0171 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6515 - loss: 1.7743 - val_accuracy: 0.5976 - val_loss: 1.8005 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6812 - loss: 1.6184 - val_accuracy: 0.5935 - val_loss: 1.8364 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6952 - loss: 1.4952 - val_accuracy: 0.4818 - val_loss: 2.5419 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7356 - loss: 1.3358 - val_accuracy: 0.6704 - val_loss: 1.4844 - learning_rate: 5.0000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7572 - loss: 1.2228 - val_accuracy: 0.7296 - val_loss: 1.3103 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7690 - loss: 1.1544 - val_accuracy: 0.6405 - val_loss: 1.6433 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7829 - loss: 1.1131 - val_accuracy: 0.7287 - val_loss: 1.2913 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7878 - loss: 1.0670 - val_accuracy: 0.5028 - val_loss: 2.2935 - learning_rate: 5.0000e-04
#
#  Training with dropout_rate = 0.5
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 60ms/step - accuracy: 0.2524 - loss: 3.6459 - val_accuracy: 0.1895 - val_loss: 3.5610 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4621 - loss: 2.7180 - val_accuracy: 0.1895 - val_loss: 3.6601 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5595 - loss: 2.2761 - val_accuracy: 0.1911 - val_loss: 4.0201 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6287 - loss: 1.9779 - val_accuracy: 0.5765 - val_loss: 2.1205 - learning_rate: 5.0000e-04
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6481 - loss: 1.8443 - val_accuracy: 0.3725 - val_loss: 3.3230 - learning_rate: 5.0000e-04
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6833 - loss: 1.7338 - val_accuracy: 0.5101 - val_loss: 2.1997 - learning_rate: 5.0000e-04
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7030 - loss: 1.6084 - val_accuracy: 0.4615 - val_loss: 2.2830 - learning_rate: 2.5000e-04
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7323 - loss: 1.5153 - val_accuracy: 0.7174 - val_loss: 1.5754 - learning_rate: 2.5000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7290 - loss: 1.4671 - val_accuracy: 0.7117 - val_loss: 1.5293 - learning_rate: 2.5000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7397 - loss: 1.4255 - val_accuracy: 0.3093 - val_loss: 2.9395 - learning_rate: 2.5000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7584 - loss: 1.3461 - val_accuracy: 0.5822 - val_loss: 1.9048 - learning_rate: 2.5000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7841 - loss: 1.2582 - val_accuracy: 0.7239 - val_loss: 1.4459 - learning_rate: 1.2500e-04
#  Best dropout_rate = 0.3 with accuracy = 0.7943

# %%
# ==== Explore Batch Size ====

batch_sizes = [16, 32, 64]
batch_results = {}

for bs in batch_sizes:
    print(f"\n Training with batch_size = {bs}")

    model = build_cnn_model(
        num_layers=BEST_PARAMS['num_layers'],
        dropout_rate=BEST_PARAMS['dropout_rate'],
        weight_decay=BEST_PARAMS['weight_decay']
    )

    val_acc, _ = train_model_numpy(
        model,
        X_train, y_train,
        X_val, y_val,
        optimizer_name=BEST_PARAMS['optimizer'],
        learning_rate=BEST_PARAMS['learning_rate'],
        batch_size=bs
    )

    batch_results[bs] = val_acc

# Plot
plt.figure()
plt.plot(batch_results.keys(), batch_results.values(), marker='o')
plt.title('Validation Accuracy vs. Batch Size')
plt.xlabel('Batch Size')
plt.ylabel('Validation Accuracy')
plt.grid(True)
plt.show()

# Update best batch size
BEST_PARAMS['batch_size'] = max(batch_results, key=batch_results.get)
print(f"\n Best batch_size = {BEST_PARAMS['batch_size']} with accuracy = {batch_results[BEST_PARAMS['batch_size']]:.4f}")
# Out:
#  Training with batch_size = 16
# Epoch 1/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.2928 - loss: 3.4795 - val_accuracy: 0.1798 - val_loss: 3.6794 - learning_rate: 0.0010
# Epoch 2/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4467 - loss: 2.6300 - val_accuracy: 0.4656 - val_loss: 2.5265 - learning_rate: 0.0010
# Epoch 3/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5486 - loss: 2.1552 - val_accuracy: 0.4429 - val_loss: 2.5890 - learning_rate: 0.0010
# Epoch 4/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5980 - loss: 1.8563 - val_accuracy: 0.5142 - val_loss: 1.9952 - learning_rate: 0.0010
# Epoch 5/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6215 - loss: 1.6547 - val_accuracy: 0.5684 - val_loss: 1.7805 - learning_rate: 0.0010
# Epoch 6/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6537 - loss: 1.5031 - val_accuracy: 0.4405 - val_loss: 2.7425 - learning_rate: 0.0010
# Epoch 7/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6665 - loss: 1.4094 - val_accuracy: 0.4615 - val_loss: 2.3713 - learning_rate: 0.0010
# Epoch 8/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7120 - loss: 1.2310 - val_accuracy: 0.7126 - val_loss: 1.2346 - learning_rate: 5.0000e-04
# Epoch 9/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7438 - loss: 1.1331 - val_accuracy: 0.6453 - val_loss: 1.4458 - learning_rate: 5.0000e-04
# Epoch 10/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7553 - loss: 1.0753 - val_accuracy: 0.6688 - val_loss: 1.3573 - learning_rate: 5.0000e-04
# Epoch 11/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7993 - loss: 0.9617 - val_accuracy: 0.6923 - val_loss: 1.3447 - learning_rate: 2.5000e-04
# Epoch 12/12
# 437/437 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8244 - loss: 0.8550 - val_accuracy: 0.7733 - val_loss: 1.0825 - learning_rate: 2.5000e-04
#
#  Training with batch_size = 32
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 59ms/step - accuracy: 0.2857 - loss: 3.5631 - val_accuracy: 0.1757 - val_loss: 5.4183 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4848 - loss: 2.5878 - val_accuracy: 0.2008 - val_loss: 3.6051 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5832 - loss: 2.1849 - val_accuracy: 0.2372 - val_loss: 3.4434 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6313 - loss: 1.9378 - val_accuracy: 0.4850 - val_loss: 2.2641 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6656 - loss: 1.7542 - val_accuracy: 0.6008 - val_loss: 1.9553 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6824 - loss: 1.5981 - val_accuracy: 0.6437 - val_loss: 1.6945 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7117 - loss: 1.4607 - val_accuracy: 0.6040 - val_loss: 1.8627 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7281 - loss: 1.3444 - val_accuracy: 0.5150 - val_loss: 2.0860 - learning_rate: 0.0010
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7649 - loss: 1.2012 - val_accuracy: 0.7700 - val_loss: 1.1762 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7910 - loss: 1.0878 - val_accuracy: 0.7595 - val_loss: 1.1523 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8130 - loss: 1.0124 - val_accuracy: 0.7595 - val_loss: 1.1463 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8162 - loss: 0.9809 - val_accuracy: 0.7968 - val_loss: 1.0198 - learning_rate: 5.0000e-04
#
#  Training with batch_size = 64
# Epoch 1/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 40s 131ms/step - accuracy: 0.2954 - loss: 3.4326 - val_accuracy: 0.1757 - val_loss: 4.3654 - learning_rate: 0.0010
# Epoch 2/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5135 - loss: 2.6228 - val_accuracy: 0.1757 - val_loss: 5.8220 - learning_rate: 0.0010
# Epoch 3/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5849 - loss: 2.2798 - val_accuracy: 0.1757 - val_loss: 4.9677 - learning_rate: 0.0010
# Epoch 4/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6494 - loss: 1.9959 - val_accuracy: 0.1749 - val_loss: 3.4153 - learning_rate: 5.0000e-04
# Epoch 5/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6778 - loss: 1.8820 - val_accuracy: 0.2834 - val_loss: 3.1678 - learning_rate: 5.0000e-04
# Epoch 6/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7069 - loss: 1.7722 - val_accuracy: 0.4623 - val_loss: 2.3878 - learning_rate: 5.0000e-04
# Epoch 7/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7286 - loss: 1.6641 - val_accuracy: 0.5676 - val_loss: 2.0425 - learning_rate: 5.0000e-04
# Epoch 8/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7350 - loss: 1.5950 - val_accuracy: 0.6534 - val_loss: 1.8257 - learning_rate: 5.0000e-04
# Epoch 9/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7516 - loss: 1.4898 - val_accuracy: 0.2915 - val_loss: 5.7574 - learning_rate: 5.0000e-04
# Epoch 10/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7774 - loss: 1.4200 - val_accuracy: 0.4964 - val_loss: 2.7653 - learning_rate: 5.0000e-04
# Epoch 11/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8097 - loss: 1.3118 - val_accuracy: 0.2421 - val_loss: 7.8699 - learning_rate: 2.5000e-04
# Epoch 12/12
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8311 - loss: 1.2374 - val_accuracy: 0.7223 - val_loss: 1.6210 - learning_rate: 2.5000e-04
#  Best batch_size = 32 with accuracy = 0.7968

# %%
# ==== Explore Weight Decay ====

weight_decays = [0.0, 1e-4, 1e-3]
decay_results = {}

for decay in weight_decays:
    print(f"\n Training with weight_decay = {decay}")
    
    model = build_cnn_model(
        num_layers=BEST_PARAMS['num_layers'],
        dropout_rate=BEST_PARAMS['dropout_rate'],
        weight_decay=decay
    )

    val_acc, _ = train_model_numpy(
        model,
        X_train, y_train,
        X_val, y_val,
        optimizer_name=BEST_PARAMS['optimizer'],
        learning_rate=BEST_PARAMS['learning_rate'],
        batch_size=BEST_PARAMS['batch_size']
    )

    decay_results[decay] = val_acc

# Plot
plt.figure()
plt.plot(decay_results.keys(), decay_results.values(), marker='o')
plt.title('Validation Accuracy vs. Weight Decay')
plt.xlabel('Weight Decay')
plt.ylabel('Validation Accuracy')
plt.grid(True)
plt.show()

# Update
BEST_PARAMS['weight_decay'] = max(decay_results, key=decay_results.get)
print(f"\n Best weight_decay = {BEST_PARAMS['weight_decay']} with accuracy = {decay_results[BEST_PARAMS['weight_decay']]:.4f}")
# Out:
#  Training with weight_decay = 0.0
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 33s 62ms/step - accuracy: 0.2870 - loss: 2.4931 - val_accuracy: 0.1757 - val_loss: 4.5619 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5033 - loss: 1.5069 - val_accuracy: 0.1895 - val_loss: 2.0863 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5901 - loss: 1.1889 - val_accuracy: 0.4138 - val_loss: 1.5891 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6376 - loss: 1.0329 - val_accuracy: 0.5603 - val_loss: 1.2935 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6779 - loss: 0.9026 - val_accuracy: 0.5571 - val_loss: 1.4563 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7057 - loss: 0.8331 - val_accuracy: 0.2316 - val_loss: 5.7057 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7382 - loss: 0.7385 - val_accuracy: 0.7255 - val_loss: 0.8012 - learning_rate: 5.0000e-04
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7717 - loss: 0.6494 - val_accuracy: 0.7547 - val_loss: 0.7141 - learning_rate: 5.0000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7845 - loss: 0.6193 - val_accuracy: 0.6227 - val_loss: 1.3008 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8123 - loss: 0.5471 - val_accuracy: 0.6559 - val_loss: 1.0968 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8282 - loss: 0.4961 - val_accuracy: 0.7668 - val_loss: 0.6894 - learning_rate: 2.5000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8556 - loss: 0.4110 - val_accuracy: 0.7992 - val_loss: 0.6900 - learning_rate: 2.5000e-04
#
#  Training with weight_decay = 0.0001
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 63ms/step - accuracy: 0.2693 - loss: 2.6417 - val_accuracy: 0.1895 - val_loss: 3.2183 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4851 - loss: 1.6884 - val_accuracy: 0.1895 - val_loss: 2.7872 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5819 - loss: 1.3347 - val_accuracy: 0.3053 - val_loss: 2.3378 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6355 - loss: 1.1513 - val_accuracy: 0.4745 - val_loss: 1.9634 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6705 - loss: 1.0275 - val_accuracy: 0.5215 - val_loss: 1.4025 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7016 - loss: 0.9613 - val_accuracy: 0.5287 - val_loss: 1.6077 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7251 - loss: 0.9058 - val_accuracy: 0.5935 - val_loss: 1.6158 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7706 - loss: 0.7758 - val_accuracy: 0.7563 - val_loss: 0.8538 - learning_rate: 5.0000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7984 - loss: 0.6974 - val_accuracy: 0.6745 - val_loss: 1.0754 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8113 - loss: 0.6543 - val_accuracy: 0.6462 - val_loss: 1.3446 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8411 - loss: 0.5726 - val_accuracy: 0.6494 - val_loss: 1.1244 - learning_rate: 2.5000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8733 - loss: 0.5041 - val_accuracy: 0.6915 - val_loss: 1.0704 - learning_rate: 2.5000e-04
#
#  Training with weight_decay = 0.001
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 60ms/step - accuracy: 0.2874 - loss: 3.5796 - val_accuracy: 0.1757 - val_loss: 3.7732 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4869 - loss: 2.6583 - val_accuracy: 0.1757 - val_loss: 3.8988 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5759 - loss: 2.1930 - val_accuracy: 0.2931 - val_loss: 3.5541 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6249 - loss: 1.9348 - val_accuracy: 0.6251 - val_loss: 1.8720 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6637 - loss: 1.7356 - val_accuracy: 0.6146 - val_loss: 1.8569 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6889 - loss: 1.5886 - val_accuracy: 0.5684 - val_loss: 1.9382 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7088 - loss: 1.4610 - val_accuracy: 0.6154 - val_loss: 1.7072 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7254 - loss: 1.3513 - val_accuracy: 0.7020 - val_loss: 1.4114 - learning_rate: 0.0010
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7486 - loss: 1.2502 - val_accuracy: 0.7085 - val_loss: 1.3709 - learning_rate: 0.0010
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7613 - loss: 1.2073 - val_accuracy: 0.5781 - val_loss: 1.7830 - learning_rate: 0.0010
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7671 - loss: 1.1582 - val_accuracy: 0.6640 - val_loss: 1.4777 - learning_rate: 0.0010
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8170 - loss: 1.0035 - val_accuracy: 0.7595 - val_loss: 1.1727 - learning_rate: 5.0000e-04
#  Best weight_decay = 0.0 with accuracy = 0.7992

# %%
# ==== Explore Optimizer ====

optimizers = ['Adam', 'SGD', 'RMSprop']
opt_results = {}

for opt in optimizers:
    print(f"\n Training with optimizer = {opt}")
    
    model = build_cnn_model(
        num_layers=BEST_PARAMS['num_layers'],
        dropout_rate=BEST_PARAMS['dropout_rate'],
        weight_decay=BEST_PARAMS['weight_decay']
    )

    val_acc, _ = train_model_numpy(
        model,
        X_train, y_train,
        X_val, y_val,
        optimizer_name=opt,
        learning_rate=BEST_PARAMS['learning_rate'],
        batch_size=BEST_PARAMS['batch_size']
    )

    opt_results[opt] = val_acc

# Plot
plt.figure()
plt.plot(opt_results.keys(), opt_results.values(), marker='o')
plt.title('Validation Accuracy vs. Optimizer')
plt.xlabel('Optimizer')
plt.ylabel('Validation Accuracy')
plt.grid(True)
plt.show()

# Update
BEST_PARAMS['optimizer'] = max(opt_results, key=opt_results.get)
print(f"\n Best optimizer = {BEST_PARAMS['optimizer']} with accuracy = {opt_results[BEST_PARAMS['optimizer']]:.4f}")
# Out:
#  Training with optimizer = Adam
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.2646 - loss: 2.6653 - val_accuracy: 0.1895 - val_loss: 2.7603 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4856 - loss: 1.5737 - val_accuracy: 0.1749 - val_loss: 2.1640 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5652 - loss: 1.2785 - val_accuracy: 0.3012 - val_loss: 1.9902 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6211 - loss: 1.0868 - val_accuracy: 0.5053 - val_loss: 1.6166 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6503 - loss: 0.9762 - val_accuracy: 0.6211 - val_loss: 1.1537 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6933 - loss: 0.8556 - val_accuracy: 0.5571 - val_loss: 1.3845 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7188 - loss: 0.8067 - val_accuracy: 0.5085 - val_loss: 1.5586 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7543 - loss: 0.6960 - val_accuracy: 0.7482 - val_loss: 0.7219 - learning_rate: 5.0000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7784 - loss: 0.6339 - val_accuracy: 0.7247 - val_loss: 0.7664 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8109 - loss: 0.5579 - val_accuracy: 0.7296 - val_loss: 0.7610 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8275 - loss: 0.4811 - val_accuracy: 0.7838 - val_loss: 0.6617 - learning_rate: 2.5000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8556 - loss: 0.4178 - val_accuracy: 0.7522 - val_loss: 0.7272 - learning_rate: 2.5000e-04
#
#  Training with optimizer = SGD
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 58ms/step - accuracy: 0.2336 - loss: 2.6451 - val_accuracy: 0.0704 - val_loss: 14.6652 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4276 - loss: 1.7180 - val_accuracy: 0.0704 - val_loss: 12.8239 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5212 - loss: 1.3849 - val_accuracy: 0.1968 - val_loss: 5.9613 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5641 - loss: 1.2142 - val_accuracy: 0.4559 - val_loss: 2.2359 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6144 - loss: 1.1082 - val_accuracy: 0.3174 - val_loss: 2.1845 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6225 - loss: 1.0424 - val_accuracy: 0.4745 - val_loss: 1.7317 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6470 - loss: 0.9988 - val_accuracy: 0.4113 - val_loss: 3.2683 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6756 - loss: 0.9327 - val_accuracy: 0.5223 - val_loss: 1.3417 - learning_rate: 0.0010
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6771 - loss: 0.9010 - val_accuracy: 0.3328 - val_loss: 2.4596 - learning_rate: 0.0010
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6933 - loss: 0.8666 - val_accuracy: 0.5830 - val_loss: 1.4245 - learning_rate: 0.0010
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7050 - loss: 0.8385 - val_accuracy: 0.4356 - val_loss: 1.9365 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7218 - loss: 0.7830 - val_accuracy: 0.5247 - val_loss: 1.4771 - learning_rate: 5.0000e-04
#
#  Training with optimizer = RMSprop
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 65ms/step - accuracy: 0.2702 - loss: 2.5770 - val_accuracy: 0.1757 - val_loss: 2.0834 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4432 - loss: 1.6397 - val_accuracy: 0.1692 - val_loss: 11.7734 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5663 - loss: 1.2628 - val_accuracy: 0.1757 - val_loss: 2.2400 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6374 - loss: 1.0111 - val_accuracy: 0.1749 - val_loss: 3.2735 - learning_rate: 5.0000e-04
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6713 - loss: 0.9122 - val_accuracy: 0.1781 - val_loss: 2.4562 - learning_rate: 5.0000e-04
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7180 - loss: 0.8048 - val_accuracy: 0.1741 - val_loss: 2.8279 - learning_rate: 2.5000e-04
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7280 - loss: 0.7483 - val_accuracy: 0.1717 - val_loss: 6.3468 - learning_rate: 2.5000e-04
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7655 - loss: 0.6867 - val_accuracy: 0.2275 - val_loss: 2.5579 - learning_rate: 1.2500e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7661 - loss: 0.6614 - val_accuracy: 0.2105 - val_loss: 6.6207 - learning_rate: 1.2500e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7838 - loss: 0.6209 - val_accuracy: 0.2753 - val_loss: 3.0958 - learning_rate: 6.2500e-05
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7837 - loss: 0.6121 - val_accuracy: 0.5360 - val_loss: 1.5188 - learning_rate: 6.2500e-05
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7973 - loss: 0.5890 - val_accuracy: 0.2502 - val_loss: 3.5598 - learning_rate: 6.2500e-05
#  Best optimizer = Adam with accuracy = 0.7838

# %%
# ==== Explore Learning Rate ====

lr_values = [0.0005, 0.001, 0.005, 0.01]
lr_results = {}

for lr in lr_values:
    print(f"\n Training with learning_rate = {lr}")
    
    model = build_cnn_model(
        num_layers=BEST_PARAMS['num_layers'],
        dropout_rate=BEST_PARAMS['dropout_rate'],
        weight_decay=BEST_PARAMS['weight_decay']
    )

    val_acc, _ = train_model_numpy(
        model,
        X_train, y_train,
        X_val, y_val,
        optimizer_name=BEST_PARAMS['optimizer'],
        learning_rate=lr,
        batch_size=BEST_PARAMS['batch_size']
    )

    lr_results[lr] = val_acc

# Plot
plt.figure()
plt.plot(lr_results.keys(), lr_results.values(), marker='o')
plt.title('Validation Accuracy vs. Learning Rate')
plt.xlabel('Learning Rate')
plt.ylabel('Validation Accuracy')
plt.grid(True)
plt.show()

# Update
BEST_PARAMS['learning_rate'] = max(lr_results, key=lr_results.get)
print(f"\n Best learning_rate = {BEST_PARAMS['learning_rate']} with accuracy = {lr_results[BEST_PARAMS['learning_rate']]:.4f}")
# Out:
#  Training with learning_rate = 0.0005
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 59ms/step - accuracy: 0.2881 - loss: 2.4468 - val_accuracy: 0.1895 - val_loss: 2.3866 - learning_rate: 5.0000e-04
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4871 - loss: 1.6587 - val_accuracy: 0.1781 - val_loss: 2.2766 - learning_rate: 5.0000e-04
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5545 - loss: 1.3550 - val_accuracy: 0.2947 - val_loss: 2.4834 - learning_rate: 5.0000e-04
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5974 - loss: 1.1689 - val_accuracy: 0.6049 - val_loss: 1.1738 - learning_rate: 5.0000e-04
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6557 - loss: 1.0111 - val_accuracy: 0.5563 - val_loss: 1.3217 - learning_rate: 5.0000e-04
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6757 - loss: 0.9359 - val_accuracy: 0.6332 - val_loss: 1.1353 - learning_rate: 5.0000e-04
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6943 - loss: 0.8483 - val_accuracy: 0.6049 - val_loss: 1.3264 - learning_rate: 5.0000e-04
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7262 - loss: 0.7670 - val_accuracy: 0.7134 - val_loss: 0.8143 - learning_rate: 5.0000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7390 - loss: 0.7237 - val_accuracy: 0.7652 - val_loss: 0.6723 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7566 - loss: 0.6745 - val_accuracy: 0.7069 - val_loss: 0.9429 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7814 - loss: 0.6225 - val_accuracy: 0.7538 - val_loss: 0.8192 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8073 - loss: 0.5387 - val_accuracy: 0.7668 - val_loss: 0.7178 - learning_rate: 2.5000e-04
#
#  Training with learning_rate = 0.001
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 60ms/step - accuracy: 0.2951 - loss: 2.4232 - val_accuracy: 0.1757 - val_loss: 3.5685 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4912 - loss: 1.5674 - val_accuracy: 0.1757 - val_loss: 2.9528 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5732 - loss: 1.2062 - val_accuracy: 0.3441 - val_loss: 1.8216 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6185 - loss: 1.0511 - val_accuracy: 0.5870 - val_loss: 1.1701 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6636 - loss: 0.9351 - val_accuracy: 0.6219 - val_loss: 1.2093 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6932 - loss: 0.8647 - val_accuracy: 0.6818 - val_loss: 0.8814 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7224 - loss: 0.7869 - val_accuracy: 0.6907 - val_loss: 0.9275 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7461 - loss: 0.7171 - val_accuracy: 0.5911 - val_loss: 1.2576 - learning_rate: 0.0010
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7841 - loss: 0.6193 - val_accuracy: 0.4623 - val_loss: 1.9476 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8209 - loss: 0.5244 - val_accuracy: 0.8008 - val_loss: 0.6122 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8254 - loss: 0.4988 - val_accuracy: 0.6194 - val_loss: 1.2550 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8439 - loss: 0.4507 - val_accuracy: 0.7652 - val_loss: 0.7791 - learning_rate: 5.0000e-04
#
#  Training with learning_rate = 0.005
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - accuracy: 0.2665 - loss: 2.4713 - val_accuracy: 0.1895 - val_loss: 2.3777 - learning_rate: 0.0050
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4508 - loss: 1.4912 - val_accuracy: 0.1830 - val_loss: 2.4702 - learning_rate: 0.0050
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5347 - loss: 1.2895 - val_accuracy: 0.2794 - val_loss: 2.6997 - learning_rate: 0.0050
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6271 - loss: 1.0497 - val_accuracy: 0.4397 - val_loss: 1.6045 - learning_rate: 0.0025
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6519 - loss: 0.9440 - val_accuracy: 0.3903 - val_loss: 1.8470 - learning_rate: 0.0025
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6933 - loss: 0.8866 - val_accuracy: 0.5385 - val_loss: 1.4545 - learning_rate: 0.0025
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7078 - loss: 0.8362 - val_accuracy: 0.5457 - val_loss: 1.4064 - learning_rate: 0.0025
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7282 - loss: 0.7907 - val_accuracy: 0.3798 - val_loss: 2.1538 - learning_rate: 0.0025
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7448 - loss: 0.7455 - val_accuracy: 0.3700 - val_loss: 2.6298 - learning_rate: 0.0025
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7694 - loss: 0.6621 - val_accuracy: 0.5717 - val_loss: 1.4227 - learning_rate: 0.0012
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7922 - loss: 0.6025 - val_accuracy: 0.5717 - val_loss: 1.4729 - learning_rate: 0.0012
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8296 - loss: 0.5031 - val_accuracy: 0.7166 - val_loss: 0.9249 - learning_rate: 6.2500e-04
#
#  Training with learning_rate = 0.01
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 60ms/step - accuracy: 0.2576 - loss: 2.5073 - val_accuracy: 0.2745 - val_loss: 2.2716 - learning_rate: 0.0100
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4537 - loss: 1.5090 - val_accuracy: 0.1870 - val_loss: 3.3313 - learning_rate: 0.0100
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4984 - loss: 1.3332 - val_accuracy: 0.4583 - val_loss: 1.4871 - learning_rate: 0.0100
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5616 - loss: 1.1959 - val_accuracy: 0.3538 - val_loss: 2.0530 - learning_rate: 0.0100
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5706 - loss: 1.1585 - val_accuracy: 0.5020 - val_loss: 1.3754 - learning_rate: 0.0100
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6265 - loss: 1.0557 - val_accuracy: 0.5263 - val_loss: 1.3315 - learning_rate: 0.0100
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6532 - loss: 0.9877 - val_accuracy: 0.6089 - val_loss: 1.1416 - learning_rate: 0.0100
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6806 - loss: 0.9097 - val_accuracy: 0.4972 - val_loss: 1.5445 - learning_rate: 0.0100
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6916 - loss: 0.8817 - val_accuracy: 0.5466 - val_loss: 1.6214 - learning_rate: 0.0100
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7230 - loss: 0.7756 - val_accuracy: 0.6130 - val_loss: 1.1631 - learning_rate: 0.0050
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7514 - loss: 0.7066 - val_accuracy: 0.6372 - val_loss: 1.0777 - learning_rate: 0.0050
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7682 - loss: 0.6565 - val_accuracy: 0.6583 - val_loss: 1.1738 - learning_rate: 0.0050
#  Best learning_rate = 0.001 with accuracy = 0.8008

# %%
# ==== Explore LR Scheduler ====

from tensorflow.keras.callbacks import ReduceLROnPlateau

scheduler_options = {
    'none': None,
    'reduce_on_plateau': ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2)
}

scheduler_results = {}

for name, sched in scheduler_options.items():
    print(f"\n Training with scheduler = {name}")

    model = build_cnn_model(
        num_layers=BEST_PARAMS['num_layers'],
        dropout_rate=BEST_PARAMS['dropout_rate'],
        weight_decay=BEST_PARAMS['weight_decay']
    )

    val_acc, _ = train_model_numpy(
        model,
        X_train, y_train,
        X_val, y_val,
        optimizer_name=BEST_PARAMS['optimizer'],
        learning_rate=BEST_PARAMS['learning_rate'],
        batch_size=BEST_PARAMS['batch_size'],
        use_scheduler=(sched is not None)
    )

    scheduler_results[name] = val_acc

# Plot
plt.figure()
plt.plot(scheduler_results.keys(), scheduler_results.values(), marker='o')
plt.title('Validation Accuracy vs. LR Scheduler')
plt.xlabel('Scheduler')
plt.ylabel('Validation Accuracy')
plt.grid(True)
plt.show()

# Update best scheduler
BEST_PARAMS['scheduler'] = max(scheduler_results, key=scheduler_results.get)
print(f"\n Best scheduler = {BEST_PARAMS['scheduler']} with accuracy = {scheduler_results[BEST_PARAMS['scheduler']]:.4f}")
# Out:
#  Training with scheduler = none
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 59ms/step - accuracy: 0.2901 - loss: 2.4345 - val_accuracy: 0.1757 - val_loss: 2.8524
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5048 - loss: 1.5393 - val_accuracy: 0.1765 - val_loss: 2.1221
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5807 - loss: 1.2192 - val_accuracy: 0.2753 - val_loss: 3.0055
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6332 - loss: 1.0488 - val_accuracy: 0.5028 - val_loss: 1.9337
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6829 - loss: 0.8975 - val_accuracy: 0.6534 - val_loss: 1.1162
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7121 - loss: 0.8169 - val_accuracy: 0.5231 - val_loss: 1.7641
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7305 - loss: 0.7470 - val_accuracy: 0.4988 - val_loss: 1.6491
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7582 - loss: 0.6747 - val_accuracy: 0.6559 - val_loss: 1.1319
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7756 - loss: 0.6342 - val_accuracy: 0.5960 - val_loss: 1.5610
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7912 - loss: 0.5878 - val_accuracy: 0.6777 - val_loss: 1.0653
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8128 - loss: 0.5381 - val_accuracy: 0.7036 - val_loss: 0.9776
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8202 - loss: 0.5247 - val_accuracy: 0.3749 - val_loss: 3.1519
#
#  Training with scheduler = reduce_on_plateau
# Epoch 1/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 54ms/step - accuracy: 0.3049 - loss: 2.4304 - val_accuracy: 0.1757 - val_loss: 3.3488 - learning_rate: 0.0010
# Epoch 2/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5062 - loss: 1.5309 - val_accuracy: 0.1757 - val_loss: 3.6041 - learning_rate: 0.0010
# Epoch 3/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5825 - loss: 1.2034 - val_accuracy: 0.3587 - val_loss: 1.7848 - learning_rate: 0.0010
# Epoch 4/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6294 - loss: 1.0622 - val_accuracy: 0.3571 - val_loss: 2.2056 - learning_rate: 0.0010
# Epoch 5/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6711 - loss: 0.9318 - val_accuracy: 0.5069 - val_loss: 1.6117 - learning_rate: 0.0010
# Epoch 6/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6953 - loss: 0.8543 - val_accuracy: 0.3895 - val_loss: 1.8115 - learning_rate: 0.0010
# Epoch 7/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7310 - loss: 0.7772 - val_accuracy: 0.3385 - val_loss: 2.3885 - learning_rate: 0.0010
# Epoch 8/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7731 - loss: 0.6628 - val_accuracy: 0.7312 - val_loss: 0.8414 - learning_rate: 5.0000e-04
# Epoch 9/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7982 - loss: 0.5798 - val_accuracy: 0.7563 - val_loss: 0.7289 - learning_rate: 5.0000e-04
# Epoch 10/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8117 - loss: 0.5473 - val_accuracy: 0.7538 - val_loss: 0.8382 - learning_rate: 5.0000e-04
# Epoch 11/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8326 - loss: 0.4856 - val_accuracy: 0.7547 - val_loss: 0.7293 - learning_rate: 5.0000e-04
# Epoch 12/12
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8599 - loss: 0.4147 - val_accuracy: 0.7636 - val_loss: 0.7359 - learning_rate: 2.5000e-04
#  Best scheduler = reduce_on_plateau with accuracy = 0.7636

# %%
# from tensorflow.keras.losses import CategoricalCrossentropy
# import tensorflow as tf
# import numpy as np

# # Use this as the loss in final training
# loss_fn = CategoricalCrossentropy(label_smoothing=0.1)

# def mixup_data(X, y, alpha=0.2):
#     if alpha > 0:
#         lam = np.random.beta(alpha, alpha)
#     else:
#         lam = 1
#     batch_size = X.shape[0]
#     index = np.random.permutation(batch_size)

#     mixed_X = lam * X + (1 - lam) * X[index]
#     y_onehot = tf.keras.utils.to_categorical(y, num_classes=NUM_CLASSES)
#     y_shuffled = tf.keras.utils.to_categorical(y[index], num_classes=NUM_CLASSES)
#     mixed_y = lam * y_onehot + (1 - lam) * y_shuffled

#     return mixed_X, mixed_y

# %%
# def get_augmented_generators(train_csv, test_csv, train_dir, test_dir,
#                              img_size=224, batch_size=32, val_split=0.15):
#     """
#     Augmented generator with rotation, shift, zoom, flip for final training.
#     """
#     train_df = pd.read_csv(train_csv)
#     test_df = pd.read_csv(test_csv)

#     train_aug = ImageDataGenerator(
#         rescale=1./255,
#         rotation_range=20,
#         width_shift_range=0.2,
#         height_shift_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True,
#         validation_split=val_split
#     )

#     test_datagen = ImageDataGenerator(rescale=1./255)

#     train_gen = train_aug.flow_from_dataframe(
#         dataframe=train_df,
#         directory=train_dir,
#         x_col='image_ID',
#         y_col='label',
#         target_size=(img_size, img_size),
#         class_mode='sparse',
#         batch_size=batch_size,
#         subset='training',
#         shuffle=True
#     )

#     val_gen = train_aug.flow_from_dataframe(
#         dataframe=train_df,
#         directory=train_dir,
#         x_col='image_ID',
#         y_col='label',
#         target_size=(img_size, img_size),
#         class_mode='sparse',
#         batch_size=batch_size,
#         subset='validation',
#         shuffle=True
#     )

#     test_gen = test_datagen.flow_from_dataframe(
#         dataframe=test_df,
#         directory=test_dir,
#         x_col='image_ID',
#         target_size=(img_size, img_size),
#         class_mode=None,
#         batch_size=1,
#         shuffle=False
#     )

#     return train_gen, val_gen, test_gen

# %%
# def final_model, history = final_train_with_mixup(
#     model,
#     X_train, y_train, X_val, y_val,
#     optimizer_name=BEST_PARAMS['optimizer'],
#     learning_rate=BEST_PARAMS['learning_rate'],
#     batch_size=BEST_PARAMS['batch_size'],
#     epochs=60
# )

    

#     opt_cls = {'Adam': Adam, 'SGD': SGD, 'RMSprop': RMSprop}[optimizer_name]
#     opt_kwargs = {'learning_rate': learning_rate}
#     if optimizer_name == 'SGD':
#         opt_kwargs['momentum'] = 0.9
#     optimizer = opt_cls(**opt_kwargs)

#     model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

#     callbacks = [
#         EarlyStopping(patience=10, monitor='val_accuracy', restore_best_weights=True),
#         ModelCheckpoint('final_model_mixup.keras', monitor='val_accuracy', save_best_only=True)
#     ]
#     if use_scheduler:
#         callbacks.insert(1, ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3))

#     history = []
#     for epoch in range(epochs):
#         print(f"\n Epoch {epoch+1}/{epochs}")
#         X_mixed, y_mixed = mixup_data(X_train, y_train, alpha=0.2)
#         hist = model.fit(
#             X_mixed, y_mixed,
#             validation_data=(X_val, tf.keras.utils.to_categorical(y_val, NUM_CLASSES)),
#             batch_size=batch_size,
#             epochs=1,
#             callbacks=callbacks,
#             verbose=1
#         )
#         history.append(hist.history)

#     return model, history

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

def augment_images(X, y):
    """
    Apply data augmentation to NumPy arrays using tf.data.
    Returns an augmented tf.data.Dataset.
    """
    def preprocess(image, label):
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_brightness(image, max_delta=0.2)
        image = tf.image.random_contrast(image, 0.8, 1.2)
        image = tf.image.random_saturation(image, 0.8, 1.2)
        image = tf.image.random_hue(image, 0.08)
        image = tf.image.random_crop(image, size=[IMG_SIZE, IMG_SIZE, CHANNELS])
        return image, label

    dataset = tf.data.Dataset.from_tensor_slices((X, y))
    dataset = dataset.map(lambda x, y: (tf.image.resize(x, [IMG_SIZE+8, IMG_SIZE+8]), y), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(buffer_size=1000).batch(BEST_PARAMS['batch_size']).prefetch(tf.data.AUTOTUNE)
    
    return dataset

# %%
# ==== Final Training ====
aug_train_dataset = augment_images(X_train, y_train)
# Rebuild model with best hyperparameters
final_model = build_cnn_model(
    num_layers=BEST_PARAMS['num_layers'],
    dropout_rate=BEST_PARAMS['dropout_rate'],
    weight_decay=BEST_PARAMS['weight_decay']
)

# Choose optimizer
opt_cls = {'Adam': Adam, 'SGD': SGD, 'RMSprop': RMSprop}[BEST_PARAMS['optimizer']]
opt_kwargs = {'learning_rate': BEST_PARAMS['learning_rate']}
if BEST_PARAMS['optimizer'] == 'SGD':
    opt_kwargs['momentum'] = 0.9
optimizer = opt_cls(**opt_kwargs)

# Label smoothing loss
loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

# Compile model
final_model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# Callbacks
callbacks = [
    EarlyStopping(patience=10, monitor='val_accuracy', restore_best_weights=True),
    ModelCheckpoint('final_model.keras', monitor='val_accuracy', save_best_only=True)
]
if BEST_PARAMS.get('use_scheduler', True):
    callbacks.insert(1, ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3))

# Train
history = final_model.fit(
    X_train/255.0, tf.keras.utils.to_categorical(y_train, NUM_CLASSES),
    validation_data=(X_val/255.0, tf.keras.utils.to_categorical(y_val, NUM_CLASSES)),
    batch_size=BEST_PARAMS['batch_size'],
    epochs=50,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 35s 74ms/step - accuracy: 0.2556 - loss: 2.6184 - val_accuracy: 0.1757 - val_loss: 6.1090 - learning_rate: 0.0010
# Epoch 2/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4699 - loss: 1.7632 - val_accuracy: 0.1960 - val_loss: 2.1418 - learning_rate: 0.0010
# Epoch 3/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5721 - loss: 1.4278 - val_accuracy: 0.3660 - val_loss: 1.8118 - learning_rate: 0.0010
# Epoch 4/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6393 - loss: 1.2781 - val_accuracy: 0.5700 - val_loss: 1.3089 - learning_rate: 0.0010
# Epoch 5/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6748 - loss: 1.1691 - val_accuracy: 0.6462 - val_loss: 1.2166 - learning_rate: 0.0010
# Epoch 6/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7011 - loss: 1.1132 - val_accuracy: 0.6713 - val_loss: 1.1467 - learning_rate: 0.0010
# Epoch 7/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7289 - loss: 1.0438 - val_accuracy: 0.5919 - val_loss: 1.4111 - learning_rate: 0.0010
# Epoch 8/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7611 - loss: 0.9966 - val_accuracy: 0.6915 - val_loss: 1.1386 - learning_rate: 0.0010
# Epoch 9/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7673 - loss: 0.9708 - val_accuracy: 0.6478 - val_loss: 1.2611 - learning_rate: 0.0010
# Epoch 10/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7892 - loss: 0.9237 - val_accuracy: 0.7206 - val_loss: 1.1186 - learning_rate: 0.0010
# Epoch 11/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8079 - loss: 0.9006 - val_accuracy: 0.6170 - val_loss: 1.3641 - learning_rate: 0.0010
# Epoch 12/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8338 - loss: 0.8443 - val_accuracy: 0.7611 - val_loss: 1.0059 - learning_rate: 0.0010
# Epoch 13/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8377 - loss: 0.8209 - val_accuracy: 0.5984 - val_loss: 1.6025 - learning_rate: 0.0010
# Epoch 14/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8625 - loss: 0.7862 - val_accuracy: 0.6818 - val_loss: 1.1852 - learning_rate: 0.0010
# Epoch 15/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8719 - loss: 0.7611 - val_accuracy: 0.7457 - val_loss: 1.0586 - learning_rate: 0.0010
# Epoch 16/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9048 - loss: 0.7034 - val_accuracy: 0.8194 - val_loss: 0.8806 - learning_rate: 5.0000e-04
# Epoch 17/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9378 - loss: 0.6458 - val_accuracy: 0.7935 - val_loss: 0.9574 - learning_rate: 5.0000e-04
# Epoch 18/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9472 - loss: 0.6266 - val_accuracy: 0.8049 - val_loss: 0.9796 - learning_rate: 5.0000e-04
# Epoch 19/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9617 - loss: 0.6043 - val_accuracy: 0.7223 - val_loss: 1.2469 - learning_rate: 5.0000e-04
# Epoch 20/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9726 - loss: 0.5768 - val_accuracy: 0.8680 - val_loss: 0.7945 - learning_rate: 2.5000e-04
# Epoch 21/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9819 - loss: 0.5575 - val_accuracy: 0.8672 - val_loss: 0.8204 - learning_rate: 2.5000e-04
# Epoch 22/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9858 - loss: 0.5479 - val_accuracy: 0.8713 - val_loss: 0.7606 - learning_rate: 2.5000e-04
# Epoch 23/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9882 - loss: 0.5382 - val_accuracy: 0.8891 - val_loss: 0.7549 - learning_rate: 2.5000e-04
# Epoch 24/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9892 - loss: 0.5338 - val_accuracy: 0.8745 - val_loss: 0.8041 - learning_rate: 2.5000e-04
# Epoch 25/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9929 - loss: 0.5265 - val_accuracy: 0.8672 - val_loss: 0.8158 - learning_rate: 2.5000e-04
# Epoch 26/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9885 - loss: 0.5295 - val_accuracy: 0.8988 - val_loss: 0.7333 - learning_rate: 2.5000e-04
# Epoch 27/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9955 - loss: 0.5190 - val_accuracy: 0.8988 - val_loss: 0.7349 - learning_rate: 2.5000e-04
# Epoch 28/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9965 - loss: 0.5146 - val_accuracy: 0.8931 - val_loss: 0.7289 - learning_rate: 2.5000e-04
# Epoch 29/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9941 - loss: 0.5157 - val_accuracy: 0.8802 - val_loss: 0.7739 - learning_rate: 2.5000e-04
# Epoch 30/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9974 - loss: 0.5088 - val_accuracy: 0.8915 - val_loss: 0.7409 - learning_rate: 2.5000e-04
# Epoch 31/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9968 - loss: 0.5094 - val_accuracy: 0.8883 - val_loss: 0.7618 - learning_rate: 2.5000e-04
# Epoch 32/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9970 - loss: 0.5060 - val_accuracy: 0.9085 - val_loss: 0.6877 - learning_rate: 1.2500e-04
# Epoch 33/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9989 - loss: 0.4990 - val_accuracy: 0.9117 - val_loss: 0.6961 - learning_rate: 1.2500e-04
# Epoch 34/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9985 - loss: 0.4974 - val_accuracy: 0.9093 - val_loss: 0.6924 - learning_rate: 1.2500e-04
# Epoch 35/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9992 - loss: 0.4955 - val_accuracy: 0.9126 - val_loss: 0.6871 - learning_rate: 1.2500e-04
# Epoch 36/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9990 - loss: 0.4937 - val_accuracy: 0.9077 - val_loss: 0.6932 - learning_rate: 1.2500e-04
# Epoch 37/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9992 - loss: 0.4946 - val_accuracy: 0.9126 - val_loss: 0.6815 - learning_rate: 1.2500e-04
# Epoch 38/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9997 - loss: 0.4913 - val_accuracy: 0.9101 - val_loss: 0.6816 - learning_rate: 1.2500e-04
# Epoch 39/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9999 - loss: 0.4922 - val_accuracy: 0.9126 - val_loss: 0.6815 - learning_rate: 1.2500e-04
# Epoch 40/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9997 - loss: 0.4913 - val_accuracy: 0.9093 - val_loss: 0.6919 - learning_rate: 1.2500e-04
# Epoch 41/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 0.4890 - val_accuracy: 0.9077 - val_loss: 0.6894 - learning_rate: 6.2500e-05
# Epoch 42/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9998 - loss: 0.4861 - val_accuracy: 0.9166 - val_loss: 0.6756 - learning_rate: 6.2500e-05
# Epoch 43/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9998 - loss: 0.4882 - val_accuracy: 0.9134 - val_loss: 0.6690 - learning_rate: 6.2500e-05
# Epoch 44/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9989 - loss: 0.4868 - val_accuracy: 0.9158 - val_loss: 0.6697 - learning_rate: 6.2500e-05
# Epoch 45/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9998 - loss: 0.4875 - val_accuracy: 0.9077 - val_loss: 0.6824 - learning_rate: 6.2500e-05
# Epoch 46/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 0.4840 - val_accuracy: 0.9085 - val_loss: 0.6828 - learning_rate: 6.2500e-05
# Epoch 47/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9993 - loss: 0.4840 - val_accuracy: 0.9142 - val_loss: 0.6646 - learning_rate: 3.1250e-05
# Epoch 48/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 0.4834 - val_accuracy: 0.9166 - val_loss: 0.6647 - learning_rate: 3.1250e-05
# Epoch 49/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9998 - loss: 0.4836 - val_accuracy: 0.9142 - val_loss: 0.6699 - learning_rate: 3.1250e-05
# Epoch 50/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 0.4832 - val_accuracy: 0.9150 - val_loss: 0.6617 - learning_rate: 3.1250e-05

# %%
# ==== Evaluation ====

val_loss, val_acc = final_model.evaluate(
    X_val, tf.keras.utils.to_categorical(y_val, NUM_CLASSES),
    verbose=1
)
print(f"\n Final Validation Accuracy: {val_acc:.4f}")

# ==== Prediction on Test Set ====
X_test = load_test_images(pd.read_csv(TEST_CSV), TEST_IMG_DIR, img_size=IMG_SIZE)
X_test = X_test / 255.0
preds = final_model.predict(X_test, verbose=1)
pred_labels = np.argmax(preds, axis=1)

# If you have a label encoder used before
final_predictions = le.inverse_transform(pred_labels)

# Save submission (optional)
submission = pd.DataFrame({
    'image_ID': pd.read_csv(TEST_CSV)['image_ID'],
    'predicted_label': final_predictions
})
submission.to_csv('final_predictions.csv', index=False)
print(" Predictions saved to 'final_predictions.csv'")
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2269 - loss: 12.3288
#
#  Final Validation Accuracy: 0.2267
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step
#  Predictions saved to 'final_predictions.csv'

# %%
print("\n Final CNN Architecture:")
final_model.summary()
# Out:
#  Final CNN Architecture:
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_192 (Conv2D)                  │ (None, 64, 64, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_216              │ (None, 64, 64, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_193 (Conv2D)                  │ (None, 64, 64, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_217              │ (None, 64, 64, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_96 (MaxPooling2D)      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_120 (Dropout)                │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_194 (Conv2D)                  │ (None, 32, 32, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_218              │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_195 (Conv2D)                  │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_219              │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_97 (MaxPooling2D)      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_121 (Dropout)                │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_196 (Conv2D)                  │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_220              │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_197 (Conv2D)                  │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_221              │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_98 (MaxPooling2D)      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_122 (Dropout)                │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_198 (Conv2D)                  │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_222              │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_199 (Conv2D)                  │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_223              │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_99 (MaxPooling2D)      │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_123 (Dropout)                │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_24          │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_48 (Dense)                     │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_224              │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_124 (Dropout)                │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_49 (Dense)                     │ (None, 7)                   │           1,799 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,729,275 (14.23 MB)
#  Trainable params: 1,242,279 (4.74 MB)
#  Non-trainable params: 2,432 (9.50 KB)
#  Optimizer params: 2,484,564 (9.48 MB)

# %%
# ===== TRAINING HISTORY PLOTS =====

def plot_history(history):
    plt.figure(figsize=(14, 5))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Plot training results
plot_history(history)

# %%
# ===== GENERATE TEST PREDICTIONS =====

# Predict class probabilities
test_preds_probs = final_model.predict(test_gen, verbose=1)

# Take the class with the highest probability
test_preds = test_preds_probs.argmax(axis=1)

# Map back to label names using the label encoder
predicted_labels = le.inverse_transform(test_preds)

# Create submission DataFrame
submission = pd.DataFrame({
    'image_ID': test_gen.filenames,
    'label': predicted_labels
})

submission.to_csv('submission.csv', index=False)
print(" Submission file 'submission.csv' created.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15956/3872750857.py in <cell line: 0>()
#       2
#       3 # Predict class probabilities
# ----> 4 test_preds_probs = final_model.predict(test_gen, verbose=1)
#       5
#       6 # Take the class with the highest probability
#
# NameError: name 'test_gen' is not defined

# %%
import random
from tensorflow.keras.preprocessing.image import load_img
sample_indices = random.sample(range(len(test_gen.filenames)), 8)

plt.figure(figsize=(16, 8))
for i, idx in enumerate(sample_indices):
    image_path = os.path.join(TEST_IMG_DIR, test_gen.filenames[idx])
    image = load_img(image_path, target_size=(IMG_SIZE, IMG_SIZE))

    plt.subplot(2, 4, i+1)
    plt.imshow(image)
    plt.title(f"Predicted: {predicted_labels[idx]}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
print(BEST_PARAMS)
# Out:
# {'batch_size': 32, 'num_layers': 4, 'dropout_rate': 0.3, 'weight_decay': 0.0, 'optimizer': 'Adam', 'learning_rate': 0.001, 'scheduler': 'reduce_on_plateau'}

# %%
# # ===== TEST PREDICTION & SUBMISSION =====
# # Load test metadata
# import pandas as pd
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# df_test = pd.read_csv(TEST_CSV)
# # Load and preprocess test images
# df_test = pd.read_csv(TEST_CSV)
# X_test = load_test_images(df_test, TEST_IMG_DIR)
# # Standardize using training mean and std
# X_test = (X_test - m) / std
# # Create test generator
# test_gen = ImageDataGenerator().flow(
#     X_test,
#     shuffle=False,
#     batch_size=BEST_PARAMS['batch_size']
# )
# # Predict
# preds = final_model.predict(test_gen)
# pred_classes = np.argmax(preds, axis=1)
# # Map back to original labels
# pred_labels = le.inverse_transform(pred_classes)
# # Save submission.csv
# submission_df = pd.DataFrame({
#     IMAGE_COL: df_test[IMAGE_COL],
#     LABEL_COL: pred_labels
# })
# submission_df.to_csv('submission.csv', index=False)
# print("Submission file 'submission.csv' saved.")

# %%
print("all cells successfully trained ")

# %%
import os
from IPython.display import FileLink, display

# Paths (assumed already in /kaggle/working)
model_path = 'best_sports_classifier.keras'
sub_path   = 'submission.csv'
zip_path   = 'output.zip'

# 1) Zip them (if you want one download)
#    - the `-j` flag puts them in the root of the zip without folders
# !zip -j {zip_path} {model_path} {sub_path}

# 2) Display download links
display(FileLink(model_path, result_html_prefix=" Download model: "))
display(FileLink(sub_path,   result_html_prefix=" Download submission: "))
display(FileLink(zip_path,   result_html_prefix=" Download both as ZIP: "))
# Out:
# 	zip warning: name not matched: best_sports_classifier.keras
# 	zip warning: name not matched: submission.csv
#
# zip error: Nothing to do! (output.zip)
# /kaggle/working/best_sports_classifier.keras
# /kaggle/working/submission.csv
# /kaggle/working/output.zip
